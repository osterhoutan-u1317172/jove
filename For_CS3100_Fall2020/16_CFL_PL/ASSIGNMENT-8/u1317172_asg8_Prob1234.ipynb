# %% [markdown]
# <style>
# h1 {
#     border-bottom: 2px solid;
# }
# h2 {
#     border-bottom: 1px solid;
# }
# blockquote {
#     border-left: 2px solid;
#     /* background-color: #00000488; */
#     /* filter: brightness(80%); */
#     margin-left: 2em;
#     margin-right: 2em;
#     padding: 1px 2px 1px 1em;
# }
# pre {
#     border: 1px solid #88888888;
#     margin-left: 1em;
#     margin-right: 1em;
#     padding: 0.5em;
#     /*padding: 8pt 1em 8pt 1em;*/
# }
# blockquote > pre {
#     margin-left: 0.5em;
# }
# img {
#     display: block;
#     margin-left: auto;
#     margin-right: auto;
# }
# </style>
#
# # Asg-8 focuses on questions graded by the mentioned TAs
#
# ### Andrew Osterhout (u1317172)
#
# Full details are in the PDF file of Asg-8
#
# This notebook only has space for your answers

# %% [markdown]
#  * * *
#  * * *

# %% [markdown]
# # 1 (SV, 25%)
#
# ## **1.a (20%):**
# _**Note:** Draw the parse-tree separately, call it `u1234567_asg8_PT.pdf`, and include it in your `.ZIP`_
#
# ### The CFG from pg.158!
# ```
# WWBar       -> OddLen | EvenLenXO
# EvenLenXO   -> GrowOMiddle GrowXMiddle | GrowXMiddle GrowOMiddle
# GrowOMiddle -> B GrowOMiddle B | 0
# GrowXMiddle -> B GrowXMiddle B | 1
# B           -> 0 | 1
# ```
#
# ### Parse `"01011101"`:
# ```
# [WWBar
#   [EvenLenXO
#     [GrowOMiddle '0'],
#     [GrowXMiddle
#       [B '1'],
#       [GrowXMiddle
#         [B '0'],
#         [GrowXMiddle [B '1'],[GrowXMiddle '1'],[B '1']],
#         [B '0']
#       ],
#       [B '1']
#     ]
#   ]
# ]
# ```
#
# <!-- -->
# > ![Parse Tree for `"01011101"`](./u1317172_asg8_PT.png)
#
#
#
# ## **1.b (5%):**
# _**Answer Summary:** because there is no way to split the string such that both sides are odd numbered with one side having a `'0'` in the middle and the other having an `'1'` in the middle._
# - First of all `"0101"` is in $L_{ww}$ and therefore by definition can't be in $\overline{L_{ww}}$.
# - It has an even number of characters and therefore needs to go through the `EvenLenXO` grammar.
# - When trying to find a way to split the string in two,
#     one side matching the `GrowOMiddle` grammar and the other side matching the `GrowXMiddle` grammar,
#     it cannot.
# - Since the only ways to split it into two strings with odd lengths is `"0"` & `"101"` or `"010"` & `"1"`.
# - Which both options either have both strings mating the `GrowOMiddle` grammar or the `GrowXMiddle` grammar.
# - Which breaks the definition of the `EvenLenXO` grammar.

# %% [markdown]
#  * * *
#  * * *

# %% [markdown]
# # 2 (LT, 25%)
# Here is a proof that attempts to show that the language $L_{eq01} = \{ 0^n 1^n \::\: n \geq 0 \}$ is not context-free:
#
# &emsp;
# **Proof for $L_{eq01}$ not being Context-free:**
#    <br/>&emsp;&emsp;&ensp;
# **(a)** Assume there is a CFG with $|V|$ productions for this language.
#    <br/>&emsp;&emsp;&ensp;
# **(b)** Choose $N = 2^{|V|+1}$ as in the CFL Pumping Lemma.
#    <br/>&emsp;&emsp;&ensp;
# **(c)** Consider the string $0^N1^N \in L_{eq01}$
#    <br/>&emsp;&emsp;&ensp;
# **(d)** Consider the band of $0$'s in $0^N$.
#   It harbors a pump $vxy$ which is surely less than or equal to $N$ in length.
#    <br/>&emsp;&emsp;&ensp;
# **(e)** By pumping,
#     we make the number of $0$'s differ from the number of $1$'s.
#   Hence the language is not context-free.
#
# ## **2.a:** Find the flaw in the proof:
# It did not considering all possible pumps that the string could have,
#   only one possible pump,
#   and the PL theorem for CFL's require that no possible pump in a string
#   in a given language
#   fulfill all 3 requirements in for the PL theorem.
# If the pump was set up so that $v$ & $y$ contained the same number of
#   $0$'s and $1$'1 respectively from the string,
#   when you pump them up or down,
#   the resulting strings will all be in the Language.
# Satisfying the requirements of the PL theorem for being a CFL.
#
#
# ## **2.b:** Propose a CFG for this language:
# ```
# N: {S}
# Σ: {ε, 0, 1}
# S: S
# P: {
#   "S -> 0S1 | ε"
# }
# ```

# %% [markdown]
#  * * *
#  * * *

# %% [markdown]
# # 3 (XL, 25%)
# Show that $L_{eq01\overline{2}} \cap L_{eq\overline{0}12}$ is not Context free.
# Where $L_{eq01\overline{2}}$ and $L_{eq\overline{0}12}$ are both known to be CFL's.
# (_i.e._ prove that CFL's are not closed under intersection.)
# $$ L_{eq01\overline{2}} = \{ 0^m 1^m 2^n \::\: m,n\geq0 \} \;\text{ is }\textsf{ a CFL} $$
# $$ L_{eq\overline{0}12} = \{ 0^n 1^m 2^m \::\: m,n\geq0 \} \;\text{ is }\textsf{ a CFL} $$
#
# ### ANSWER:
# - $L_{eq01\overline{2}} \cap L_{eq\overline{0}12}$ will result in a language comprised of all the strings in $L_{eq01\overline{2}} \cup L_{eq\overline{0}12}$ where $n=m$ (_i.e._ $L_{eq01\overline{2}} \cap L_{eq\overline{0}12} = L_{eq012}$).
#    $$ L_{eq01\overline{2}} \cap L_{eq\overline{0}12} = L_{eq012} = \{ 0^n 1^n 2^n \::\: n\geq0 \} $$
# - Assume there is a CFG with $|V|$ productions for this language.
# - Let $N = 2^{|V|+1}$ be the pumping length associated with a CFG of this language.
# - Consider the string
#    $0^N1^N2^N \in L_{eq012},\,L_{eq01\overline{2}} \cap L_{eq\overline{0}12}$
# - The segments $v$ and $y$ of the Pumping Lemma
#    are contained within the $0^N1^N2^N$ block,
#    in the middle 1N0N block or in the last $1^N2^N$ block,
#    and in each of these cases,
#    they could also have fallen entirely within a $0^N$ block,
#    a $1^N$ block, or $2^N$ block as the case may be.
# - In each case,
#    by pumping up or down,
#    we will option a string not within
#    $L_{eq012}\,/\,L_{eq01\overline{2}} \cap L_{eq\overline{0}12}$
#    (_i.e._ the number of $0$'s & $1$'s will not match the number of $2$'s
#    or the number of $1$'s & $2$'s will not match the number of $0$'s).
# - Therefore $L_{eq012}\,/\,L_{eq01\overline{2}} \cap L_{eq\overline{0}12}$
#    cannot be a CFL.

# %% [markdown]
#  * * *
#  * * *

# %% [markdown]
# # 4 (AR, 25%)
#
# ## **4.a (5%):**
# Run the `flipperTM` for input `"001001"`,
#  computing the amount fuel consumed.
#
#     Allocating  8  tape cells to the RIGHT!
#     Detailing the halted configs now.
#     Accepted at  ('F', 6, '110110........', 93)
#     via ..
#       ->('I', 0, '001001', 100)
#       ->('I', 1, '101001', 99)
#       ->('I', 2, '111001', 98)
#       ->('I', 3, '110001', 97)
#       ->('I', 4, '110101', 96)
#       ->('I', 5, '110111', 95)
#       ->('I', 6, '110110', 94)
#       ->('F', 6, '110110........', 93)
#
#
# ## **4.b (5%):**
# Run the `DTMwpwfor` input `"001#001"` initially,
#   noting the amount of fuel consumed:
#
#     Allocating  8  tape cells to the RIGHT!
#     Detailing the halted configs now.
#     Accepted at  ('Fq6', 8, 'XXY#XXY........', 88)
#     via ..
#       ->('Iq0', 0, '001#001', 120)
#       ->('q1', 1, 'X01#001', 119)
#       ->('q1', 2, 'X01#001', 118)
#       ->('q1', 3, 'X01#001', 117)
#       ->('q2', 4, 'X01#001', 116)
#       ->('q3', 3, 'X01#X01', 115)
#       ->('q4', 2, 'X01#X01', 114)
#       ->('q4', 1, 'X01#X01', 113)
#       ->('q4', 0, 'X01#X01', 112)
#       ->('Iq0', 1, 'X01#X01', 111)
#       ->('q1', 2, 'XX1#X01', 110)
#       ->('q1', 3, 'XX1#X01', 109)
#       ->('q2', 4, 'XX1#X01', 108)
#       ->('q2', 5, 'XX1#X01', 107)
#       ->('q3', 4, 'XX1#XX1', 106)
#       ->('q3', 3, 'XX1#XX1', 105)
#       ->('q4', 2, 'XX1#XX1', 104)
#       ->('q4', 1, 'XX1#XX1', 103)
#       ->('Iq0', 2, 'XX1#XX1', 102)
#       ->('q7', 3, 'XXY#XX1', 101)
#       ->('q8', 4, 'XXY#XX1', 100)
#       ->('q8', 5, 'XXY#XX1', 99)
#       ->('q8', 6, 'XXY#XX1', 98)
#       ->('q3', 5, 'XXY#XXY', 97)
#       ->('q3', 4, 'XXY#XXY', 96)
#       ->('q3', 3, 'XXY#XXY', 95)
#       ->('q4', 2, 'XXY#XXY', 94)
#       ->('Iq0', 3, 'XXY#XXY', 93)
#       ->('q5', 4, 'XXY#XXY', 92)
#       ->('q5', 5, 'XXY#XXY', 91)
#       ->('q5', 6, 'XXY#XXY', 90)
#       ->('q5', 7, 'XXY#XXY', 89)
#       ->('Fq6', 8, 'XXY#XXY........', 88)
#
# How “acceptance” is announced.
#
# > When a possible path in the deterministic machine reaches the final state.
# > Therefore it announces acceptance by finishing processing on a final state.
#
#
# ## **4.c (5%):**
# Then run it for input `"001#010"`,
#   and describe the state transitions leading to this TM’s reject verdict.
#
#     Detailing the halted configs now.
#     Rejected at  ('q2', 5, 'XX1#X10', 107)
#     via ..
#       ->('Iq0', 0, '001#010', 120)
#       ->('q1', 1, 'X01#010', 119)
#       ->('q1', 2, 'X01#010', 118)
#       ->('q1', 3, 'X01#010', 117)
#       ->('q2', 4, 'X01#010', 116)
#       ->('q3', 3, 'X01#X10', 115)
#       ->('q4', 2, 'X01#X10', 114)
#       ->('q4', 1, 'X01#X10', 113)
#       ->('q4', 0, 'X01#X10', 112)
#       ->('Iq0', 1, 'X01#X10', 111)
#       ->('q1', 2, 'XX1#X10', 110)
#       ->('q1', 3, 'XX1#X10', 109)
#       ->('q2', 4, 'XX1#X10', 108)
#       ->('q2', 5, 'XX1#X10', 107)
#
# How does this TM announce “rejection?”.
#
# > It's deterministic so it determines rejection when there is no path for it to take given an input.
# > Therefore, it announces rejection by reaching a black hole state & therefore not ever finishing while statying on the same state until it runs out of fuel.
#
#
#
# ## **4.d (5%):**
# Run the NDTM `wwndtm` for input `"001001"` initially,
#   noting the amount of fuel consumed:
#
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the RIGHT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the RIGHT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the LEFT!
#     Detailing the halted configs now.
#     Rejected at  ('q14', 6, '001001', 163)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q14', 4, '001001', 165)
#       ->('q14', 5, '001001', 164)
#       ->('q14', 6, '001001', 163)
#     Rejected at  ('q4', 13, '........P0100Y', 152)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q14', 4, '001001', 165)
#       ->('q14', 5, '001001', 164)
#       ->('q2', 4, '00100Y', 163)
#       ->('q2', 3, '00100Y', 162)
#       ->('q2', 2, '00100Y', 161)
#       ->('q2', 1, '00100Y', 160)
#       ->('q2', 0, '00100Y', 159)
#       ->('q2', 7, '........00100Y', 158)
#       ->('q3', 8, '........00100Y', 157)
#       ->('q4', 9, '........P0100Y', 156)
#       ->('q4', 10, '........P0100Y', 155)
#       ->('q4', 11, '........P0100Y', 154)
#       ->('q4', 12, '........P0100Y', 153)
#       ->('q4', 13, '........P0100Y', 152)
#     Rejected at  ('q4', 13, '........PP102Y', 144)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q14', 4, '001001', 165)
#       ->('q2', 3, '0010X1', 164)
#       ->('q2', 2, '0010X1', 163)
#       ->('q2', 1, '0010X1', 162)
#       ->('q2', 0, '0010X1', 161)
#       ->('q2', 7, '........0010X1', 160)
#       ->('q3', 8, '........0010X1', 159)
#       ->('q4', 9, '........P010X1', 158)
#       ->('q4', 10, '........P010X1', 157)
#       ->('q4', 11, '........P010X1', 156)
#       ->('q4', 12, '........P010X1', 155)
#       ->('q10', 13, '........P01021', 154)
#       ->('q8', 12, '........P0102Y', 153)
#       ->('q8', 11, '........P0102Y', 152)
#       ->('q8', 10, '........P0102Y', 151)
#       ->('q8', 9, '........P0102Y', 150)
#       ->('q8', 8, '........P0102Y', 149)
#       ->('q3', 9, '........P0102Y', 148)
#       ->('q4', 10, '........PP102Y', 147)
#       ->('q4', 11, '........PP102Y', 146)
#       ->('q4', 12, '........PP102Y', 145)
#       ->('q4', 13, '........PP102Y', 144)
#     Accepted at  ('Fq13', 15, '........PPQ223........', 130)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q2', 2, '001X01', 165)
#       ->('q2', 1, '001X01', 164)
#       ->('q2', 0, '001X01', 163)
#       ->('q2', 7, '........001X01', 162)
#       ->('q3', 8, '........001X01', 161)
#       ->('q4', 9, '........P01X01', 160)
#       ->('q4', 10, '........P01X01', 159)
#       ->('q4', 11, '........P01X01', 158)
#       ->('q10', 12, '........P01201', 157)
#       ->('q8', 11, '........P012X1', 156)
#       ->('q8', 10, '........P012X1', 155)
#       ->('q8', 9, '........P012X1', 154)
#       ->('q8', 8, '........P012X1', 153)
#       ->('q3', 9, '........P012X1', 152)
#       ->('q4', 10, '........PP12X1', 151)
#       ->('q4', 11, '........PP12X1', 150)
#       ->('q4', 12, '........PP12X1', 149)
#       ->('q10', 13, '........PP1221', 148)
#       ->('q8', 12, '........PP122Y', 147)
#       ->('q8', 11, '........PP122Y', 146)
#       ->('q8', 10, '........PP122Y', 145)
#       ->('q8', 9, '........PP122Y', 144)
#       ->('q3', 10, '........PP122Y', 143)
#       ->('q5', 11, '........PPQ22Y', 142)
#       ->('q5', 12, '........PPQ22Y', 141)
#       ->('q5', 13, '........PPQ22Y', 140)
#       ->('q11', 14, '........PPQ223', 139)
#       ->('q9', 13, '........PPQ223........', 138)
#       ->('q9', 12, '........PPQ223........', 137)
#       ->('q9', 11, '........PPQ223........', 136)
#       ->('q9', 10, '........PPQ223........', 135)
#       ->('q3', 11, '........PPQ223........', 134)
#       ->('q12', 12, '........PPQ223........', 133)
#       ->('q12', 13, '........PPQ223........', 132)
#       ->('q12', 14, '........PPQ223........', 131)
#       ->('Fq13', 15, '........PPQ223........', 130)
#     Rejected at  ('q4', 10, '........P0Y001', 161)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q2', 1, '00Y001', 166)
#       ->('q2', 0, '00Y001', 165)
#       ->('q2', 7, '........00Y001', 164)
#       ->('q3', 8, '........00Y001', 163)
#       ->('q4', 9, '........P0Y001', 162)
#       ->('q4', 10, '........P0Y001', 161)
#     Rejected at  ('q12', 10, '........P2Y001', 159)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q2', 0, '0X1001', 167)
#       ->('q2', 7, '........0X1001', 166)
#       ->('q3', 8, '........0X1001', 165)
#       ->('q4', 9, '........PX1001', 164)
#       ->('q10', 10, '........P21001', 163)
#       ->('q8', 9, '........P2Y001', 162)
#       ->('q8', 8, '........P2Y001', 161)
#       ->('q3', 9, '........P2Y001', 160)
#       ->('q12', 10, '........P2Y001', 159)
#     Rejected at  ('q6', 9, '........X01001', 166)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q2', 7, '........X01001', 168)
#       ->('q3', 8, '........X01001', 167)
#       ->('q6', 9, '........X01001', 166)
#
#
# How “acceptance” is announced.
#
# > It's announced by reaching a final state which should only be reachable when the NTM determines it should accept the string.
# > Therefore it announced acceptance by finishing on a final state
#
#
# ## **4.e (5%):**
# Then run it for input `"001010"`,
#   and describe the state transitions leading to this TM’s reject verdict.
#
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the RIGHT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the RIGHT!
#     Allocating  8  tape cells to the LEFT!
#     Allocating  8  tape cells to the LEFT!
#     Detailing the halted configs now.
#     Rejected at  ('q14', 6, '001001', 163)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q14', 4, '001001', 165)
#       ->('q14', 5, '001001', 164)
#       ->('q14', 6, '001001', 163)
#     Rejected at  ('q4', 13, '........P0100Y', 152)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q14', 4, '001001', 165)
#       ->('q14', 5, '001001', 164)
#       ->('q2', 4, '00100Y', 163)
#       ->('q2', 3, '00100Y', 162)
#       ->('q2', 2, '00100Y', 161)
#       ->('q2', 1, '00100Y', 160)
#       ->('q2', 0, '00100Y', 159)
#       ->('q2', 7, '........00100Y', 158)
#       ->('q3', 8, '........00100Y', 157)
#       ->('q4', 9, '........P0100Y', 156)
#       ->('q4', 10, '........P0100Y', 155)
#       ->('q4', 11, '........P0100Y', 154)
#       ->('q4', 12, '........P0100Y', 153)
#       ->('q4', 13, '........P0100Y', 152)
#     Rejected at  ('q4', 13, '........PP102Y', 144)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q14', 4, '001001', 165)
#       ->('q2', 3, '0010X1', 164)
#       ->('q2', 2, '0010X1', 163)
#       ->('q2', 1, '0010X1', 162)
#       ->('q2', 0, '0010X1', 161)
#       ->('q2', 7, '........0010X1', 160)
#       ->('q3', 8, '........0010X1', 159)
#       ->('q4', 9, '........P010X1', 158)
#       ->('q4', 10, '........P010X1', 157)
#       ->('q4', 11, '........P010X1', 156)
#       ->('q4', 12, '........P010X1', 155)
#       ->('q10', 13, '........P01021', 154)
#       ->('q8', 12, '........P0102Y', 153)
#       ->('q8', 11, '........P0102Y', 152)
#       ->('q8', 10, '........P0102Y', 151)
#       ->('q8', 9, '........P0102Y', 150)
#       ->('q8', 8, '........P0102Y', 149)
#       ->('q3', 9, '........P0102Y', 148)
#       ->('q4', 10, '........PP102Y', 147)
#       ->('q4', 11, '........PP102Y', 146)
#       ->('q4', 12, '........PP102Y', 145)
#       ->('q4', 13, '........PP102Y', 144)
#     Accepted at  ('Fq13', 15, '........PPQ223........', 130)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q14', 3, '001001', 166)
#       ->('q2', 2, '001X01', 165)
#       ->('q2', 1, '001X01', 164)
#       ->('q2', 0, '001X01', 163)
#       ->('q2', 7, '........001X01', 162)
#       ->('q3', 8, '........001X01', 161)
#       ->('q4', 9, '........P01X01', 160)
#       ->('q4', 10, '........P01X01', 159)
#       ->('q4', 11, '........P01X01', 158)
#       ->('q10', 12, '........P01201', 157)
#       ->('q8', 11, '........P012X1', 156)
#       ->('q8', 10, '........P012X1', 155)
#       ->('q8', 9, '........P012X1', 154)
#       ->('q8', 8, '........P012X1', 153)
#       ->('q3', 9, '........P012X1', 152)
#       ->('q4', 10, '........PP12X1', 151)
#       ->('q4', 11, '........PP12X1', 150)
#       ->('q4', 12, '........PP12X1', 149)
#       ->('q10', 13, '........PP1221', 148)
#       ->('q8', 12, '........PP122Y', 147)
#       ->('q8', 11, '........PP122Y', 146)
#       ->('q8', 10, '........PP122Y', 145)
#       ->('q8', 9, '........PP122Y', 144)
#       ->('q3', 10, '........PP122Y', 143)
#       ->('q5', 11, '........PPQ22Y', 142)
#       ->('q5', 12, '........PPQ22Y', 141)
#       ->('q5', 13, '........PPQ22Y', 140)
#       ->('q11', 14, '........PPQ223', 139)
#       ->('q9', 13, '........PPQ223........', 138)
#       ->('q9', 12, '........PPQ223........', 137)
#       ->('q9', 11, '........PPQ223........', 136)
#       ->('q9', 10, '........PPQ223........', 135)
#       ->('q3', 11, '........PPQ223........', 134)
#       ->('q12', 12, '........PPQ223........', 133)
#       ->('q12', 13, '........PPQ223........', 132)
#       ->('q12', 14, '........PPQ223........', 131)
#       ->('Fq13', 15, '........PPQ223........', 130)
#     Rejected at  ('q4', 10, '........P0Y001', 161)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q14', 2, '001001', 167)
#       ->('q2', 1, '00Y001', 166)
#       ->('q2', 0, '00Y001', 165)
#       ->('q2', 7, '........00Y001', 164)
#       ->('q3', 8, '........00Y001', 163)
#       ->('q4', 9, '........P0Y001', 162)
#       ->('q4', 10, '........P0Y001', 161)
#     Rejected at  ('q12', 10, '........P2Y001', 159)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q14', 1, '001001', 168)
#       ->('q2', 0, '0X1001', 167)
#       ->('q2', 7, '........0X1001', 166)
#       ->('q3', 8, '........0X1001', 165)
#       ->('q4', 9, '........PX1001', 164)
#       ->('q10', 10, '........P21001', 163)
#       ->('q8', 9, '........P2Y001', 162)
#       ->('q8', 8, '........P2Y001', 161)
#       ->('q3', 9, '........P2Y001', 160)
#       ->('q12', 10, '........P2Y001', 159)
#     Rejected at  ('q6', 9, '........X01001', 166)
#     via ..
#       ->('Iq0', 0, '001001', 170)
#       ->('q14', 0, '001001', 169)
#       ->('q2', 7, '........X01001', 168)
#       ->('q3', 8, '........X01001', 167)
#       ->('q6', 9, '........X01001', 166)
#
#
# How does this TM announce “rejection?”.
#
# > By having all of it's non-deterministic paths stop processing and therefore the machine stops working without reaching a final state.

# %% [markdown]
#  * * *
#  * * *

# %% [markdown]
# # END
